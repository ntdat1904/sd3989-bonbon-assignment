# %% [markdown]
# # Setup environment
# - Create conda env `conda create langchain python=3.11`
# - Set the "langchain" env that has been just created as the running env in VS code

# %% [markdown]
# Install  python-dotenv

# %%
! pip install python-dotenv
# Out:
# 46.67s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: python-dotenv in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (1.1.0)

# %% [markdown]
# Install langchain and openai package

# %%
! pip install langchain openai
# Out:
# 56.44s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: langchain in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (0.3.26)
# Requirement already satisfied: openai in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (1.90.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (0.3.66)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (0.4.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (4.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai) (0.10.0)
# Requirement already satisfied: sniffio in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai) (4.67.1)
# Requirement already satisfied: httpcore==1.* in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain) (0.23.0)

# %%
! pip install --upgrade pip langchain
! pip install langchain_community langchain_openai python-dotenv pypdf chromadb pysqlite3-binary
# Out:
# Requirement already satisfied: pip in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (25.1.1)
# Requirement already satisfied: langchain in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (0.3.26)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (0.3.66)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (0.4.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (4.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: langchain_community in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (0.3.26)
# Requirement already satisfied: langchain_openai in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (0.3.27)
# Requirement already satisfied: python-dotenv in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (1.1.1)
# Requirement already satisfied: pypdf in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (5.7.0)
# Requirement already satisfied: chromadb in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (1.0.13)
# Requirement already satisfied: pysqlite3-binary in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (0.5.4)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain_community) (0.3.66)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain_community) (0.3.26)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain_community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain_community) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain_community) (3.12.13)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain_community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain_community) (2.10.0)
# Requirement already satisfied: langsmith>=0.1.125 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain_community) (0.4.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain_community) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain_community) (2.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain<1.0.0,>=0.3.26->langchain_community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain<1.0.0,>=0.3.26->langchain_community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain_community) (4.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain_community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain_community) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from requests<3,>=2->langchain_community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from requests<3,>=2->langchain_community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from requests<3,>=2->langchain_community) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.1.0)
# Requirement already satisfied: openai<2.0.0,>=1.86.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain_openai) (1.90.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain_openai) (0.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain_openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain_openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain_openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain_openai) (0.10.0)
# Requirement already satisfied: sniffio in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain_openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain_openai) (4.67.1)
# Requirement already satisfied: httpcore==1.* in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain_openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain_openai) (0.16.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain_openai) (2024.11.6)
# Requirement already satisfied: build>=1.0.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pybase64>=1.4.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.3)
# Requirement already satisfied: posthog>=2.4.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (1.73.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: rich>=10.11.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (4.24.0)
# Requirement already satisfied: pyproject_hooks in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb) (0.25.1)
# Requirement already satisfied: six>=1.9.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langsmith>=0.1.125->langchain_community) (0.23.0)
# Requirement already satisfied: coloredlogs in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.55b1)
# Requirement already satisfied: backoff>=1.10.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb) (0.33.0)
# Requirement already satisfied: filelock in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.5.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.1.5)
# Requirement already satisfied: click>=8.0.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: uvloop>=0.15.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)

# %% [markdown]
# # Init variables

# %% [markdown]
# You need to set value of `OPENAI_API_KEY` that you get from the training team in the .env file

# %%
import os
from dotenv import load_dotenv

# Load environment variables from the .env file
load_dotenv()

AZURE_OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
AZURE_OPENAI_API_VERSION = os.getenv("AZURE_OPENAI_API_VERSION")
AZURE_OPENAI_EMBEDDING_MODEL = os.getenv("OPENAI_EMBEDDING_MODEL")
AZURE_OPENAI_DEPLOYMENT_NAME = os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT")

# %% [markdown]
# # Overviews
# The BonBon FAQ.pdf file contains frequently asked questions and answers for customer support scenario. The topics are around IT related issue troubleshooting such as networking, software, hardware. You are requested to provide a solution to build a chat bot capable of answering the user questions with LangChain.

# %% [markdown]
# ## Assignment 1: Document Indexing (mandatory)

# %% [markdown]
# - The content of BonBon FAQ.pdf should be indexed to the local Chroma vector DB from where the chatbot can lookup the appropriate information to answer questions.
# - Should use some embedding model such as Azure Open AI text-embedding-3-small to create vectors, feel free to use any other open source embedding model if it works.

# %%
# Install core packages
! pip install --upgrade langchain langchain-openai langchain-community langchain-chroma

# Install supporting packages
! pip install --upgrade chromadb tiktoken pypdf duckduckgo-search python-dotenv pysqlite3-binary
# Out:
# 85964.30s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: langchain in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (0.3.26)
# Requirement already satisfied: langchain-openai in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (0.3.24)
# Collecting langchain-openai
#   Downloading langchain_openai-0.3.27-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: langchain-community in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (0.3.26)
# Requirement already satisfied: langchain-chroma in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (0.2.4)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (0.3.66)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (0.4.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (4.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2025.6.15)
# Requirement already satisfied: greenlet>=1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: openai<2.0.0,>=1.86.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-openai) (1.90.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from openai<2.0.0,>=1.86.0->langchain-openai) (4.67.1)
# Requirement already satisfied: httpcore==1.* in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai) (0.16.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-community) (3.12.13)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-community) (2.10.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-community) (2.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: chromadb>=1.0.9 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langchain-chroma) (1.0.13)
# Requirement already satisfied: build>=1.0.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.2.2.post1)
# Requirement already satisfied: pybase64>=1.4.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (0.34.3)
# Requirement already satisfied: posthog>=2.4.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.34.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (1.73.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (33.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (3.10.18)
# Requirement already satisfied: rich>=10.11.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb>=1.0.9->langchain-chroma) (4.24.0)
# Requirement already satisfied: pyproject_hooks in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from build>=1.0.3->chromadb>=1.0.9->langchain-chroma) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb>=1.0.9->langchain-chroma) (0.25.1)
# Requirement already satisfied: six>=1.9.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.9->langchain-chroma) (0.6.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: coloredlogs in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (25.2.10)
# Requirement already satisfied: protobuf in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (5.29.5)
# Requirement already satisfied: sympy in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb>=1.0.9->langchain-chroma) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb>=1.0.9->langchain-chroma) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.9->langchain-chroma) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from opentelemetry-sdk>=1.2.0->chromadb>=1.0.9->langchain-chroma) (0.55b1)
# Requirement already satisfied: backoff>=1.10.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb>=1.0.9->langchain-chroma) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from rich>=10.11.0->chromadb>=1.0.9->langchain-chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from rich>=10.11.0->chromadb>=1.0.9->langchain-chroma) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=1.0.9->langchain-chroma) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma) (0.33.0)
# Requirement already satisfied: filelock in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma) (2025.5.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.9->langchain-chroma) (1.1.5)
# Requirement already satisfied: click>=8.0.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from typer>=0.9.0->chromadb>=1.0.9->langchain-chroma) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from typer>=0.9.0->chromadb>=1.0.9->langchain-chroma) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (0.6.4)
# Requirement already satisfied: uvloop>=0.15.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.9->langchain-chroma) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=1.0.9->langchain-chroma) (1.3.0)
# Downloading langchain_openai-0.3.27-py3-none-any.whl (70 kB)
# Installing collected packages: langchain-openai
#   Attempting uninstall: langchain-openai
#     Found existing installation: langchain-openai 0.3.24
#     Uninstalling langchain-openai-0.3.24:
#       Successfully uninstalled langchain-openai-0.3.24
# Successfully installed langchain-openai-0.3.27
# 85979.74s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: chromadb in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (1.0.13)
# Requirement already satisfied: tiktoken in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (0.9.0)
# Requirement already satisfied: pypdf in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (5.6.1)
# Collecting pypdf
#   Downloading pypdf-5.7.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: duckduckgo-search in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (8.0.4)
# Requirement already satisfied: python-dotenv in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (1.1.0)
# Collecting python-dotenv
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pysqlite3-binary in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (0.5.4)
# Requirement already satisfied: build>=1.0.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (2.11.7)
# Requirement already satisfied: pybase64>=1.4.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.34.3)
# Requirement already satisfied: numpy>=1.22.5 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (2.3.1)
# Requirement already satisfied: posthog>=2.4.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (4.14.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (1.34.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (1.73.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from chromadb) (4.24.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from tiktoken) (2.32.4)
# Requirement already satisfied: click>=8.1.8 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from duckduckgo-search) (8.2.1)
# Requirement already satisfied: primp>=0.15.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from duckduckgo-search) (0.15.0)
# Requirement already satisfied: lxml>=5.3.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from duckduckgo-search) (5.4.0)
# Requirement already satisfied: packaging>=19.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (24.2)
# Requirement already satisfied: pyproject_hooks in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: anyio in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: certifi in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from jsonschema>=4.19.0->chromadb) (0.25.1)
# Requirement already satisfied: six>=1.9.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: urllib3>=1.24.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.55b1)
# Requirement already satisfied: backoff>=1.10.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (3.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from pydantic>=1.9->chromadb) (0.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb) (0.33.0)
# Requirement already satisfied: filelock in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.5.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.1.5)
# Requirement already satisfied: shellingham>=1.3.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: uvloop>=0.15.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/datnguyent4/miniconda3/envs/langchain-demo/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Downloading pypdf-5.7.0-py3-none-any.whl (305 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv, pypdf
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.1.0
#     Uninstalling python-dotenv-1.1.0:
#       Successfully uninstalled python-dotenv-1.1.0
#   Attempting uninstall: pypdf
#     Found existing installation: pypdf 5.6.1
#     Uninstalling pypdf-5.6.1:
#       Successfully uninstalled pypdf-5.6.1
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pypdf]32m1/2 [pypdf]
# Successfully installed pypdf-5.7.0 python-dotenv-1.1.1

# %%
from dotenv import load_dotenv
import os
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import AzureOpenAIEmbeddings
from langchain_chroma import Chroma

# Load environment variables
load_dotenv()

# Configuration
PDF_PATH = "data/BonBon FAQ.pdf"
CHROMA_DIR = "./chroma_db"

# Initialize embedding model
embedding = AzureOpenAIEmbeddings(
    azure_deployment=os.environ["AZURE_OPENAI_EMBEDDING_DEPLOYMENT"],
    api_key=os.environ["AZURE_OPENAI_API_KEY"],
    azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"],
    api_version=os.environ["AZURE_OPENAI_API_VERSION"]
)

# Load and split PDF into chunks
loader = PyPDFLoader(PDF_PATH)
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=150)
pages = loader.load_and_split(splitter)

# Create Chroma vector store with persistence
vectordb = Chroma.from_documents(
    documents=pages,
    embedding=embedding,
    persist_directory=CHROMA_DIR
)

# Persist to disk only if supported
if hasattr(vectordb, "persist"):
    vectordb.persist()

print("✅ Indexed FAQ and built Chroma vector DB")
# Out:
# ✅ Indexed FAQ and built Chroma vector DB

# %% [markdown]
# ## Assignment 2: Building Chatbot (mandatory)
# - You are requested to build a chatbot solution for customer support scenario using Conversational ReAct agent supported in LangChain
# - The chatbot is able to support user to answer FAQs in the sample BonBon FAQ.pdf file.
# - The chatbot should use Azure Open AI GPT-4o LLM as the reasoning engine.
# - The chatbot should be context aware, meaning that it should be able to chat with users in the conversation manner.
# - The agent is equipped the following tools:
#   - Internet Search: Help the chatbot automatically find out more about something using Duck Duck Go internet search
#   - Knowledge Base Search: Help the chatbot to lookup information in the private knowledge base
# - In case user asks for information related to topics in the BonBon FAQ.pdf file such as internet connection, printer, malware issues the chatbot must use the private knowledge base, otherwise it should search on the internet to answer the question.
# - In the answer of chatbot, it should mention the source file and the page that the answer belongs to, for example the answer should mention "BonBon FQA.pdf (page 2)"

# %%
from dotenv import load_dotenv
import os

from langchain_openai import AzureChatOpenAI, AzureOpenAIEmbeddings
from langchain_chroma import Chroma
from langchain.agents import Tool
from langchain.tools import DuckDuckGoSearchRun
from langchain.chains import RetrievalQA
from langchain.memory import ConversationBufferWindowMemory
from langchain_core.runnables import RunnableLambda

class BonBonChatbot:
    def __init__(self):
        load_dotenv()
        self._load_environment_variables()
        self._initialize_embedding()
        self._load_vectorstore()
        self._initialize_llm()
        self._initialize_memory()
        self._setup_retrieval_chain()
        self._setup_tools()

    def _load_environment_variables(self):
        self.api_key = os.getenv("OPENAI_API_KEY")
        self.azure_embedding_deployment = os.getenv("AZURE_OPENAI_EMBEDDING_DEPLOYMENT")
        self.azure_chat_deployment = os.getenv("AZURE_OPENAI_CHAT_DEPLOYMENT")
        self.azure_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
        self.azure_endpoint_gpt = os.getenv("AZURE_OPENAI_ENDPOINT_GPT")
        self.api_version = os.getenv("AZURE_OPENAI_API_VERSION")

    def _initialize_embedding(self):
        self.embedding = AzureOpenAIEmbeddings(
            azure_deployment=self.azure_embedding_deployment,
            api_key=self.api_key,
            azure_endpoint=self.azure_endpoint,
            api_version=self.api_version,
        )

    def _load_vectorstore(self):
        my_path = os.path.expanduser("./chroma_db")
        self.vectordb = Chroma(persist_directory=my_path, embedding_function=self.embedding)

    def _initialize_llm(self):
        self.model = AzureChatOpenAI(
            azure_deployment=self.azure_chat_deployment,
            api_key=self.api_key,
            azure_endpoint=self.azure_endpoint_gpt,
            api_version=self.api_version,
            temperature=0.2,
        )

    def _initialize_memory(self):
        self.memory = ConversationBufferWindowMemory(
            return_messages=True,
            k=5
        )

    def _setup_retrieval_chain(self):
        self.qa = RetrievalQA.from_chain_type(
            llm=self.model,
            retriever=self.vectordb.as_retriever(search_kwargs={"k": 5}),
            return_source_documents=True,
            verbose=False,
        )

    def _custom_qa_with_source(self, query):
        docs = self.vectordb.as_retriever(search_kwargs={"k": 1}).get_relevant_documents(query)
        if not docs:
            return "I don't know."
        doc = docs[0]
        chunk = doc.page_content.strip()
        meta = doc.metadata
        source = meta.get("source", "BonBon FAQ.pdf")
        page = meta.get("page", "unknown")
        try:
            page_num = int(page) + 1
        except Exception:
            page_num = page

        result = self.qa.invoke({"query": query})
        answer = result["result"].strip()
        if len(answer) < 5 or answer == "...":
            answer = chunk

        return f"{answer}\n\n(Source: {source} (page {page_num}))"

    def _setup_tools(self):
        self.tools = [
            Tool(
                name="Retrieve Answer",
                func=self._custom_qa_with_source,
                description="Use this to answer questions about BonBon FAQ topics like internet connection, printer, malware, etc. Always cite the source and page number.",
            ),
            Tool(
                name="Search",
                func=DuckDuckGoSearchRun().run,
                description="Use this for anything else or if the KB cannot answer the question.",
            ),
        ]

    def interact(self):
        print("💬 Chatbot Ready! (type 'exit' to quit)\n")
        turn = 1
        while True:
            user_input = input("User: ")
            if user_input.lower() == "exit":
                break

            print("→ Trying knowledge base (FAQ) tool first…")
            response = self.tools[0].func(user_input)
            if (
                "don't know" in response.strip().lower()
                or response.strip() == ""
                or response is None
            ):
                print("→ No FAQ answer found, using search tool instead.")
                response = self.tools[1].func(user_input)
            else:
                print("→ Answered from knowledge base.")

            print("\n" + "=" * 60)
            print(f"🟦 Question {turn}: {user_input}\n")
            print(f"🤖 Answer:\n{response}")
            print("=" * 60 + "\n")
            turn += 1


if __name__ == "__main__":
    bot = BonBonChatbot()
    bot.interact()
# Out:
# 💬 Chatbot Ready! (type 'exit' to quit)
#
# → Trying knowledge base (FAQ) tool first…
# → Answered from knowledge base.
#
# ============================================================
# 🟦 Question 1: How do I connect to the Any Corp’s Corporate VPN (Virtual Private Network)?
#
# 🤖 Answer:
# To connect to Any Corp’s Corporate VPN, follow these steps:
#
# ### 1. **Obtain VPN Credentials**
#    - Contact your company's IT department to get the necessary credentials for connecting to the VPN. These typically include:
#      - Username
#      - Password
#      - VPN server address (and possibly additional details).
#
# ### 2. **Install VPN Software (if required)**
#    - If Any Corp provides custom VPN client software, download and install it on your computer or device. The IT department will guide you on where to find the software.
#
# ### 3. **Configure VPN Settings (if using built-in clients)**
#    - If Any Corp uses standard VPN protocols (e.g., PPTP, L2TP, IPSec, OpenVPN), you can use the built-in VPN client on your operating system.
#
# #### For **Windows**:
#    - Go to **Settings** > **Network & Internet** > **VPN**.
#    - Click **Add a VPN connection**.
#    - Enter the VPN server address, your username, and password as provided by your IT department.
#    - Configure additional settings if required by your company.
#
# #### For **macOS**:
#    - Open **System Preferences** > **Network**.
#    - Click the **+** button to add a new connection.
#    - Select **VPN** as the interface and choose the appropriate VPN type (e.g., L2TP, IPSec).
#    - Enter the VPN server address, username, and password provided by your IT department.
#    - Configure additional settings if required.
#
# ### 4. **Connect to the VPN**
#    - Once the VPN is set up, select the VPN connection and click **Connect**.
#    - Enter your credentials if prompted.
#
# If you encounter any issues, reach out to your IT department for assistance.
#
# (Source: data/BonBon FAQ.pdf (page 11))
# ============================================================
#
# → Trying knowledge base (FAQ) tool first…
# → Answered from knowledge base.
#
# ============================================================
# 🟦 Question 2: My computer is infected with malware. What steps should I take to remove it?
#
# 🤖 Answer:
# Here are the steps you should take to remove malware from your computer:
#
# 1. **Disconnect from the Internet**:
#    - Immediately disconnect your computer from the internet to prevent the malware from spreading or sending data to its source.
#
# 2. **Enter Safe Mode**:
#    - Restart your computer and boot into Safe Mode. This limits the malware's ability to operate.
#
# 3. **Install Antivirus Software**:
#    - If you don't already have antivirus software installed, download and install a trusted antivirus program.
#
# 4. **Scan for Malware**:
#    - Run a full system scan using your antivirus software to detect and identify the malware.
#
# 5. **Remove the Malware**:
#    - Follow the instructions provided by your antivirus software to remove the detected malware. This often involves quarantining or deleting infected files and cleaning your system.
#
# 6. **Update Your Operating System and Software**:
#    - Ensure your operating system and all installed software are up to date. Malware often exploits vulnerabilities in outdated software.
#
# 7. **Change Passwords**:
#    - If you suspect the malware has accessed sensitive information, change passwords for important accounts, such as email, online banking, and social media.
#
# 8. **Restore or Reinstall the Operating System (if necessary)**:
#    - In severe cases, you may need to reinstall your operating system to ensure complete removal of the malware. Back up your important data before doing this.
#
# 9. **Install Preventive Measures**:
#    - Install a reliable antivirus program and enable real-time protection.
#    - Use a firewall and avoid downloading files or clicking links from untrusted sources.
#
# By following these steps, you can remove the malware and protect your computer from future infections.
#
# (Source: data/BonBon FAQ.pdf (page 10))
# ============================================================
#
# → Trying knowledge base (FAQ) tool first…
# → Answered from knowledge base.
#
# ============================================================
# 🟦 Question 3: My computer is infected with malware. What steps should I take to remove it?
#
# 🤖 Answer:
# To remove malware from your computer, follow these steps:
#
# 1. **Disconnect from the internet**:
#    - Disconnect your computer from the internet to prevent the malware from spreading or sending data to its source.
#
# 2. **Run a trusted antivirus program**:
#    - If you don't already have antivirus software installed, download and install a trusted program. Popular options include Malwarebytes, Norton, or Bitdefender.
#
# 3. **Remove the malware**:
#    - Run a full system scan using your antivirus software. Follow its instructions to quarantine or delete infected files and clean your system.
#
# 4. **Update your operating system and software**:
#    - Ensure your operating system and all installed software are up to date. Malware often exploits vulnerabilities in outdated software.
#
# 5. **Change passwords**:
#    - If you suspect the malware has accessed sensitive information, change passwords for important accounts, such as email, online banking, and social media.
#
# 6. **Restore or reinstall the operating system (if necessary)**:
#    - In severe cases, you may need to reinstall your operating system to ensure complete removal of the malware. Back up important data before doing this.
#
# 7. **Install preventive measures**:
#    - Install antivirus software and enable a firewall to protect your system from future infections. Avoid downloading files or clicking links from untrusted sources.
#
# By following these steps, you can effectively remove malware and safeguard your computer.
#
# (Source: data/BonBon FAQ.pdf (page 10))
# ============================================================
#
# → Trying knowledge base (FAQ) tool first…
# → Answered from knowledge base.
#
# ============================================================
# 🟦 Question 4: How do I access shared network drives?
#
# 🤖 Answer:
# To access shared network drives, follow these steps:
#
# ### 1. **Map the Network Drive:**
#    - Open **File Explorer** and go to **"This PC."**
#    - Click on **"Computer"** in the top menu and select **"Map network drive."**
#    - Choose a drive letter (e.g., Z:) from the dropdown menu.
#    - Enter the **UNC path** of the shared drive (e.g., `\\server\share`).
#    - If you want the drive to be available every time you log in, check the box for **"Reconnect at sign-in."**
#    - Click **"Finish."**
#
# ### 2. **Access the Shared Drive:**
#    - If you've mapped the drive, it will appear under **"This PC"** with the assigned drive letter.
#    - If you haven't mapped the drive, you can directly access it by entering the **UNC path** (e.g., `\\server\share`) in the address bar of **File Explorer** and pressing **Enter.**
#
# ### 3. **Provide Credentials (if required):**
#    - If the shared drive requires authentication, a window will pop up asking for a username and password.
#    - Enter your credentials.
#    - Check **"Remember my credentials"** if you want to avoid entering them every time.
#
# Once these steps are completed, you should be able to access the shared network drive.
#
# (Source: data/BonBon FAQ.pdf (page 9))
# ============================================================
#
# → Trying knowledge base (FAQ) tool first…
# → Answered from knowledge base.
#
# ============================================================
# 🟦 Question 5: How do I access shared network drives?
#
# 🤖 Answer:
# To access shared network drives, follow these steps:
#
# ### 1. **Map the Network Drive**:
#    - Open **File Explorer** and go to **This PC**.
#    - Click on the **Computer** tab in the top menu and select **Map network drive**.
#    - Choose a drive letter (e.g., Z:) from the dropdown menu.
#    - Enter the **UNC path** of the shared drive (e.g., `\\server\share`).
#    - If you want the drive to be available every time you log in, check the box for **Reconnect at sign-in**.
#    - Click **Finish**.
#
# ### 2. **Access the Shared Drive**:
#    - If you mapped the drive, it will appear under **This PC** with the assigned drive letter.
#    - If you didn’t map the drive, you can directly access it by entering the **UNC path** (e.g., `\\server\share`) in the address bar of File Explorer and pressing **Enter**.
#
# ### 3. **Provide Credentials (if required)**:
#    - If the shared drive requires authentication, a window will pop up asking for a username and password.
#    - Enter your credentials.
#    - To avoid entering them every time, check **Remember my credentials**.
#
# Once done, you should have access to the shared network drive.
#
# (Source: data/BonBon FAQ.pdf (page 9))
# ============================================================
#
# → Trying knowledge base (FAQ) tool first…
# → Answered from knowledge base.
#
# ============================================================
# 🟦 Question 6:
#
# 🤖 Answer:
# It seems you haven't provided a specific question or request. Could you clarify what you'd like to know or discuss?
#
# (Source: data/BonBon FAQ.pdf (page 14))
# ============================================================
#
# → Trying knowledge base (FAQ) tool first…
# → Answered from knowledge base.
#
# ============================================================
# 🟦 Question 7: I can't print. What should I check or do to fix the issue?
#
# 🤖 Answer:
# Here are some steps you can take to troubleshoot and resolve your printing issue:
#
# 1. **Check Printer Connection**: Ensure your printer is properly connected to your computer or network. Verify that cables are securely plugged in or that the wireless connection is active.
#
# 2. **Check Printer Status**: Make sure the printer is powered on and not showing any error messages (e.g., paper jam, low ink/toner).
#
# 3. **Set the Correct Printer**: Confirm that the correct printer is selected as the default in your computer's settings.
#
# 4. **Check for Paper and Ink/Toner**: Ensure there is enough paper in the tray and that ink or toner levels are sufficient.
#
# 5. **Restart Printer and Computer**: Turn off your printer and computer, wait a few seconds, and then turn them back on.
#
# 6. **Clear Print Queue**: Open the print queue on your computer and cancel any stuck or pending print jobs.
#
# 7. **Test with a Different Document or Application**: Try printing from a different document or application to see if the issue is specific to one file or program. If other files print successfully, the problem may be with the original document or application.
#
# 8. **Restart Print Spooler Service (Windows)**:
#    - Open the "Services" application on your computer.
#    - Locate the "Print Spooler" service.
#    - Right-click on it and select "Restart." This clears the print spooler and can resolve certain printing issues.
#
# 9. **Reinstall Printer Software**: Uninstall and reinstall the printer software or drivers to ensure they are up-to-date and functioning correctly.
#
# 10. **Check for Updates**: Ensure your printer drivers and operating system are updated to the latest versions.
#
# If none of these steps resolve the issue, consult your printer's user manual or contact the manufacturer's support team for further assistance.
#
# (Source: data/BonBon FAQ.pdf (page 8))
# ============================================================
#
# → Trying knowledge base (FAQ) tool first…
# → Answered from knowledge base.
#
# ============================================================
# 🟦 Question 8: I can't print. What should I check or do to fix the issue?
#
# 🤖 Answer:
# Here are some steps you can take to troubleshoot and resolve printing issues:
#
# 1. **Check Printer Connection**: Ensure your printer is properly connected to your computer or network. If it's a wired printer, check the USB or Ethernet cable. For wireless printers, verify the Wi-Fi connection.
#
# 2. **Check Printer Status**: Make sure the printer is turned on and has paper loaded. Also, check for any error messages or blinking lights on the printer.
#
# 3. **Set Printer as Default**: Ensure the printer you are trying to use is set as the default printer on your computer.
#
# 4. **Check Ink or Toner Levels**: Verify that the printer has sufficient ink or toner to complete the print job.
#
# 5. **Clear Print Queue**: Open the print queue on your computer and clear any stuck or pending print jobs.
#
# 6. **Restart Printer and Computer**: Turn off your printer and computer, wait a few seconds, and then turn them back on.
#
# 7. **Update Printer Drivers**: Check if your printer drivers are up to date. Visit the printer manufacturer's website to download and install the latest drivers.
#
# 8. **Test with a Different Document or Application**: Try printing from a different document or application to see if the issue is specific to one file or program. If other documents print successfully, the problem may lie in the original file or software.
#
# 9. **Restart Print Spooler Service (Windows)**: Open the "Services" application on your computer, locate the "Print Spooler" service, right-click on it, and select "Restart." This clears the print spooler and can resolve certain printing issues.
#
# 10. **Reinstall Printer Software**: Uninstall the printer software from your computer and reinstall it using the latest version from the manufacturer's website.
#
# If none of these steps resolve the issue, you may need to contact the printer manufacturer's support team for further assistance.
#
# (Source: data/BonBon FAQ.pdf (page 8))
# ============================================================
#
# → Trying knowledge base (FAQ) tool first…
# → Answered from knowledge base.
#
# ============================================================
# 🟦 Question 9: How do I install a software application?
#
# 🤖 Answer:
# 1. Any Corp does not permit the installation of software applications without prior approval.
# 2. Please check Any Corp’s Intranet page > Approved Software Catalogue.
# 3. Find the software you wish to install and follow the instructions in the read.me file, which downloads automatically with the installation file.
#
# (Source: data/BonBon FAQ.pdf (page 7))
# ============================================================
#
# → Trying knowledge base (FAQ) tool first…
# → Answered from knowledge base.
#
# ============================================================
# 🟦 Question 10:
#
# 🤖 Answer:
# It seems like your message is empty. Could you clarify or provide more details about your question?
#
# (Source: data/BonBon FAQ.pdf (page 14))
# ============================================================

# %% [markdown]
# ## Assignment 3: Build a new assistant based on BonBon source code (optional)
# The objective
# - Run the code and index the sample BonBon FAQ.pdf file to Azure Cognitive Search
# - Explore the code and implement a new assistant that has the same behavior as above
# - Explore other features such as RBACs, features on admin portal
#
# Please contact the training team in case you need to get the source code of BonBon.
